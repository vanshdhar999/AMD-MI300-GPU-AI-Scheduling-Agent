# %%
from flask import Flask, request, jsonify
from threading import Thread
import json

# %%
app = Flask(__name__)
received_data = []

# %%
# def your_meeting_assistant(data): 
#     import sys
#     import os
#     sys.path.append(os.getcwd())

#     from scheduling_engine import meeting_assistant

#     print("✅ Centralized Agent loaded successfully!")

    
#     # Your Agentic AI Calls 
#     data["EventStart"] = ""
#     data["EventEnd"] = ""
#     data["Duration_mins"] = ""
#     return data
from agent import your_meeting_assistant

# %%
@app.route('/receive', methods=['POST'])
def receive():
    data = request.get_json()
    print(f"\n Received: {json.dumps(data, indent=2)}")
    new_data = your_meeting_assistant(data)  # Your AI Meeting Assistant Function Call
    received_data.append(data)
    print(f"\n\n\n Sending:\n {json.dumps(new_data, indent=2)}")
    return jsonify(new_data)

def run_flask():
    app.run(host='0.0.0.0', port=5000)

# %%
# Start Flask in a background thread
Thread(target=run_flask, daemon=True).start()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://134.199.207.38:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [20/Jul/2025 06:45:38] "POST /receive HTTP/1.1" 400 -
# INFO:werkzeug:127.0.0.1 - - [20/Jul/2025 06:46:34] "POST /receive HTTP/1.1" 400 -
# INFO:werkzeug:127.0.0.1 - - [20/Jul/2025 06:46:50] "POST /receive HTTP/1.1" 400 -
# INFO:meeting_assistant_fixed:Processing meeting request 6118b54f-907b-4451-8d48-dd13d76033d5
# INFO:meeting_assistant_fixed:Attendees: ['userone.amd@gmail.com', 'usertwo.amd@gmail.com', 'userthree.amd@gmail.com']
#  Received: {
#   "Request_id": "6118b54f-907b-4451-8d48-dd13d76033d5",
#   "Datetime": "19-07-2025T12:34:55",
#   "Location": "IISc Bangalore",
#   "From": "userone.amd@gmail.com",
# ...
